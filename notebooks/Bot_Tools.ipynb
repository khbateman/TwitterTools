# %%
import sys; sys.path.insert(0, '..')
from TwitterTools.bot_tools import *
import keyring


get_recent_emails(host = 'imappro.zoho.com',
                  username=keyring.get_password("system", "MY_EMAIL"),
                  password=keyring.get_password("system", "MY_EMAIL_PW"))
